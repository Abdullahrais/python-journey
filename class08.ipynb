# %% [markdown]
# FUNCTION WITH RETURN KEYWORD

# %%
lenght=int(input("enter your lenght")):
breadth=int(input("enter your breadth")):
height=int(input("enter your height")):
area,volume = cal_value(lenght,breadth,height)

# %%
def cal_value(lenght,breath,height):
    area_of_squre=lenght*breath
    volume=lenght*breath*height
    return area_of_squre,volumn

# %%
cal_value(3,4,5)

# %%
def room_area(length,breadth):
    area = length*breadth
    return area
room_area(6,4)

# %%
# lenght=int(input("enter your lenght")):
# area =lenght*lenght

# %%
# lenght=int(input("enter your lenght"))
# area =lenght*lenght

# breadth=int(input("enter your breadth"))
# height=int(input("enter your height"))
# vol=lenght*breadth*height

# pi=22/7
# radius=float(input("enter your radius"))
# cir=pi*radius**2

# %%
def full_name(first_name,last_name,middle_name=""):
    return f'{first_name} {middle_name} {last_name}'

# %%
full_name("mehmood","hassan")

# %%
full_name("mehmood","hassan","ul")

# %%
def full_name(first_name,last_name,middle_name=""):
    return f'{first_name} {middle_name} {last_name}'
print(full_name("mehmood","hassan","ul").upper())

# %%
def calculationc(num1,num2):
    def add(num1,num2):
        return num1 + num2
    def subtract(num1,num2):
        return num1 - num2
    print(add(num1,num2))
    print(subtract(num1,num2))

# %%
calculation(5,6)

# %%
# def add(num1,num2):
#        return num1 + num2
#     def subtract(num1,num2):
#         return num1 - num2
#     print(add(num1,num2))
#     print(subtract(num1,num2))

# %%
def add (num1,num2,*num3):
    print(num1)
    print(num2)
    print(*num3)
    added=num1+num2
    for i in num:
        added+=1
        print(added)

# %%
add(3,4,5)
# Out:
# 3
# 4
# 5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 add(3,4,5)
#
# Cell In[18], line 6, in add(num1, num2, *num3)
#       2     print(num1)
#       3     print(num2)
#       4     print(*num3)
#       5     added=num1+num2
# ----> 6     for i in num:
#       7         added+=1
#       8         print(added)
#
# NameError: name 'num' is not defined

# %% [markdown]
# | Operator | Naam                     | Matlab            |
# | -------- | ------------------------ | ----------------- |
# | `==`     | Equal To                 | Barabar hai       |
# | `!=`     | Not Equal To             | Barabar nahi hai  |
# | `>`      | Greater Than             | Bada hai          |
# | `<`      | Less Than                | Chhota hai        |
# | `>=`     | Greater Than or Equal To | Bada ya barabar   |
# | `<=`     | Less Than or Equal To    | Chhota ya barabar |
